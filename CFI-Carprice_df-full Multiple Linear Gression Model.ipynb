# %%
import pandas as pd
import matplotlib.pyplot as plot
import statsmodels.api as stats
import numpy as np

# %%
carprice_df =pd.read_csv(r"C:\Users\dnsim\OneDrive\Documents\CarPrice.csv")

# %% [markdown]
# # Assessing the data

# %%
carprice_df.shape
# Out:
# (205, 26)

# %%
carprice_df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
carprice_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
#review all column names, count in each row for null values, and data type

# %%
carprice_df.select_dtypes(include='object').nunique()
# Out:
# CarName           147
# fueltype            2
# aspiration          2
# doornumber          2
# carbody             5
# drivewheel          3
# enginelocation      2
# enginetype          7
# cylindernumber      7
# fuelsystem          8
# dtype: int64

# %%
carprice_df=carprice_df.drop(columns=['car_ID', 'CarName'])

# %% [markdown]
# # Basic Multiple Regression Model

# %%
#Y is what you are looking to solve for/predict
#X is what you are using to predict Y with

Y_basic=carprice_df.price
X_basic=stats.add_constant(carprice_df[['enginesize','curbweight','peakrpm','citympg']])

# %%
model_basic=stats.OLS(Y_basic, X_basic)
results_basic = model_basic.fit()

# %%
print(results_basic.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.818
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     225.0
# Date:                Thu, 18 May 2023   Prob (F-statistic):           7.62e-73
# Time:                        06:55:07   Log-Likelihood:                -1957.7
# No. Observations:                 205   AIC:                             3925.
# Df Residuals:                     200   BIC:                             3942.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.022e+04   5937.020     -5.090      0.000   -4.19e+04   -1.85e+04
# enginesize   115.6496     11.023     10.492      0.000      93.914     137.385
# curbweight     5.7152      1.102      5.186      0.000       3.542       7.888
# peakrpm        2.7200      0.606      4.486      0.000       1.524       3.916
# citympg       10.8265     65.239      0.166      0.868    -117.817     139.470
# ==============================================================================
# Omnibus:                       19.678   Durbin-Watson:                   0.708
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.801
# Skew:                           0.489   Prob(JB):                     1.02e-08
# Kurtosis:                       4.831   Cond. No.                     1.42e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.42e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # FULL MULTIPLE REGRESSION MODEL

# %%
carprice_df.select_dtypes(exclude='object').corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_90fe3_row0_col0,#T_90fe3_row1_col1,#T_90fe3_row2_col2,#T_90fe3_row3_col3,#T_90fe3_row4_col4,#T_90fe3_row5_col5,#T_90fe3_row6_col6,#T_90fe3_row7_col7,#T_90fe3_row8_col8,#T_90fe3_row9_col9,#T_90fe3_row10_col10,#T_90fe3_row11_col11,#T_90fe3_row12_col12,#T_90fe3_row13_col13,#T_90fe3_row14_col14{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_90fe3_row0_col1,#T_90fe3_row7_col8{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_90fe3_row0_col2,#T_90fe3_row5_col0{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_90fe3_row0_col3{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_90fe3_row0_col4,#T_90fe3_row4_col0,#T_90fe3_row5_col13,#T_90fe3_row9_col11,#T_90fe3_row10_col12,#T_90fe3_row11_col8,#T_90fe3_row11_col9,#T_90fe3_row12_col7,#T_90fe3_row12_col10,#T_90fe3_row13_col1,#T_90fe3_row13_col2,#T_90fe3_row13_col3,#T_90fe3_row13_col5,#T_90fe3_row13_col6,#T_90fe3_row13_col7,#T_90fe3_row13_col14{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_90fe3_row0_col5,#T_90fe3_row12_col4{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_90fe3_row0_col6{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_90fe3_row0_col7{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_90fe3_row0_col8,#T_90fe3_row14_col13{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_90fe3_row0_col9{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_90fe3_row0_col10,#T_90fe3_row4_col14{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_90fe3_row0_col11{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_90fe3_row0_col12{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_90fe3_row0_col13,#T_90fe3_row7_col4{
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }#T_90fe3_row0_col14{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_90fe3_row1_col0,#T_90fe3_row12_col14{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_90fe3_row1_col2,#T_90fe3_row3_col5,#T_90fe3_row5_col2,#T_90fe3_row6_col14{
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }#T_90fe3_row1_col3,#T_90fe3_row1_col5{
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }#T_90fe3_row1_col4,#T_90fe3_row4_col1,#T_90fe3_row10_col7{
#             background-color:  #f5a081;
#             color:  #000000;
#         }#T_90fe3_row1_col6{
#             background-color:  #f59c7d;
#             color:  #000000;
#         }#T_90fe3_row1_col7{
#             background-color:  #f7b497;
#             color:  #000000;
#         }#T_90fe3_row1_col8{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_90fe3_row1_col9,#T_90fe3_row4_col7{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_90fe3_row1_col10{
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }#T_90fe3_row1_col11,#T_90fe3_row2_col13{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_90fe3_row1_col12,#T_90fe3_row2_col8{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_90fe3_row1_col13,#T_90fe3_row11_col4{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_90fe3_row1_col14,#T_90fe3_row2_col7,#T_90fe3_row2_col10,#T_90fe3_row7_col6{
#             background-color:  #f4987a;
#             color:  #000000;
#         }#T_90fe3_row2_col0,#T_90fe3_row5_col11,#T_90fe3_row7_col12,#T_90fe3_row11_col1{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_90fe3_row2_col1,#T_90fe3_row5_col3{
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }#T_90fe3_row2_col3,#T_90fe3_row5_col14{
#             background-color:  #d55042;
#             color:  #000000;
#         }#T_90fe3_row2_col4,#T_90fe3_row7_col1{
#             background-color:  #f7b79b;
#             color:  #000000;
#         }#T_90fe3_row2_col5{
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }#T_90fe3_row2_col6{
#             background-color:  #ec7f63;
#             color:  #000000;
#         }#T_90fe3_row2_col9,#T_90fe3_row11_col13{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_90fe3_row2_col11{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_90fe3_row2_col12{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_90fe3_row2_col14,#T_90fe3_row6_col2,#T_90fe3_row14_col2{
#             background-color:  #eb7d62;
#             color:  #000000;
#         }#T_90fe3_row3_col0{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_90fe3_row3_col1{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_90fe3_row3_col2,#T_90fe3_row14_col5{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_90fe3_row3_col4{
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }#T_90fe3_row3_col6,#T_90fe3_row6_col3{
#             background-color:  #e57058;
#             color:  #000000;
#         }#T_90fe3_row3_col7,#T_90fe3_row6_col1{
#             background-color:  #f6a586;
#             color:  #000000;
#         }#T_90fe3_row3_col8,#T_90fe3_row9_col0,#T_90fe3_row9_col8{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_90fe3_row3_col9,#T_90fe3_row14_col4{
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }#T_90fe3_row3_col10{
#             background-color:  #ee8468;
#             color:  #000000;
#         }#T_90fe3_row3_col11{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_90fe3_row3_col12{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_90fe3_row3_col13,#T_90fe3_row6_col13{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_90fe3_row3_col14,#T_90fe3_row14_col3{
#             background-color:  #e26952;
#             color:  #000000;
#         }#T_90fe3_row4_col2{
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }#T_90fe3_row4_col3{
#             background-color:  #edd2c3;
#             color:  #000000;
#         }#T_90fe3_row4_col5{
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }#T_90fe3_row4_col6{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_90fe3_row4_col8,#T_90fe3_row10_col13,#T_90fe3_row12_col6{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_90fe3_row4_col9,#T_90fe3_row13_col9{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_90fe3_row4_col10,#T_90fe3_row4_col13{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_90fe3_row4_col11{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_90fe3_row4_col12{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_90fe3_row5_col1{
#             background-color:  #e36b54;
#             color:  #000000;
#         }#T_90fe3_row5_col4{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_90fe3_row5_col6{
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }#T_90fe3_row5_col7{
#             background-color:  #f18d6f;
#             color:  #000000;
#         }#T_90fe3_row5_col8{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_90fe3_row5_col9{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_90fe3_row5_col10,#T_90fe3_row10_col5{
#             background-color:  #e16751;
#             color:

# %%
#drop columns that have high correlations to remove some of the complexity of the model (.85 and higher?)
carprice_df=carprice_df.drop(columns=['carlength', 'carwidth','highwaympg'])

# %%
#One Hot Encoding

# %%
dummy = pd.get_dummies(carprice_df.select_dtypes(include ='object'), drop_first = True)

# %%
carprice_df=pd.concat([carprice_df.select_dtypes(exclude='object'), dummy], axis=1)

# %%
# we can repeat the above process where we remove highly correclated variables now including the one hot encoded features

# %%
carprice_df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_e1233_row0_col0,#T_e1233_row1_col1,#T_e1233_row2_col2,#T_e1233_row3_col3,#T_e1233_row4_col4,#T_e1233_row5_col5,#T_e1233_row6_col6,#T_e1233_row7_col7,#T_e1233_row8_col8,#T_e1233_row9_col9,#T_e1233_row10_col10,#T_e1233_row11_col11,#T_e1233_row12_col12,#T_e1233_row13_col13,#T_e1233_row14_col14,#T_e1233_row15_col15,#T_e1233_row16_col16,#T_e1233_row17_col17,#T_e1233_row18_col18,#T_e1233_row19_col19,#T_e1233_row20_col20,#T_e1233_row21_col21,#T_e1233_row22_col22,#T_e1233_row23_col23,#T_e1233_row24_col24,#T_e1233_row25_col25,#T_e1233_row26_col26,#T_e1233_row27_col27,#T_e1233_row27_col33,#T_e1233_row28_col28,#T_e1233_row29_col29,#T_e1233_row30_col30,#T_e1233_row31_col31,#T_e1233_row32_col32,#T_e1233_row33_col27,#T_e1233_row33_col33,#T_e1233_row34_col34,#T_e1233_row35_col35,#T_e1233_row36_col36,#T_e1233_row37_col37,#T_e1233_row38_col38,#T_e1233_row39_col39,#T_e1233_row40_col40{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T

#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_e1233_row0_col18,#T_e1233_row8_col31,#T_e1233_row10_col22,#T_e1233_row16_col15{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_e1233_row0_col19,#T_e1233_row9_col0,#T_e1233_row11_col7,#T_e1233_row32_col11{
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }#T_e1233_row0_col20,#T_e1233_row2_col4,#T_e1233_row6_col16,#T_e1233_row13_col23,#T_e1233_row17_col30,#T_e1233_row18_col5,#T_e1233_row18_col19,#T_e1233_row23_col11,#T_e1233_row23_col13,#T_e1233_row24_col16,#T_e1233_row30_col17,#T_e1233_row36_col4{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_e1233_row0_col21,#T_e1233_row0_col35,#T_e1233_row2_col12,#T_e1233_row22_col0,#T_e1233_row22_col34,#T_e1233_row25_col17,#T_e1233_row27_col38,#T_e1233_row32_col34,#T_e1233_row33_col38,#T_e1233_row37_col34,#T_e1233_row38_col0,#T_e1233_row39_col30,#T_e1233_row40_col34{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_e1233_row0_col22,#T_e1233_row3_col37,#T_e1233_row9_col31,#T_e1233_row18_col32,#T_e1233_row22_col31,#T_e1233_row24_col15,#T_e1233_row30_col32,#T_e1233_row32_col31,#T_e1233_row37_col31,#T_e1233_row39_col15,#T_e1233_row40_col31{
#             background-col

# %%
carprice_df = carprice_df.drop(columns=['compressionratio','drivewheel_fwd', 'enginetype_rotor', 'fuelsystem_4bbl', 'fuelsystem_idi'])

# %%
carprice_df.shape
# Out:
# (205, 36)

# %% [markdown]
# # Test/Train split

# %%
train_df=carprice_df.sample(frac=0.7, random_state=99)
test_df=carprice_df.drop(train_df.index)

# %%
train_df.shape
# Out:
# (144, 36)

# %% [markdown]
# # Fitting the Linear Regression Model

# %%
Y_train= train_df.price
X_train= stats.add_constant(train_df.drop(columns =['price']))

# %%
model_carprice = stats.OLS(Y_train,X_train)
results_carprice = model_carprice.fit()

# %%
print(resluts_carprice.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     48.60
# Date:                Thu, 18 May 2023   Prob (F-statistic):           1.43e-51
# Time:                        19:12:37   Log-Likelihood:                -1299.3
# No. Observations:                 144   AIC:                             2669.
# Df Residuals:                     109   BIC:                             2773.
# Df Model:                          34
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  -1.11e+04   1.58e+04     -0.701      0.485   -4.25e+04    2.03e+04
# symboling                52.4219    281.161      0.186      0.852    -504.830     609.673
# wheelbase               130.7325    115.953      1.127      0.262     -99.083     360.548
# carheight                78.5564    166.169      0.473      0.637    -250.784     407.897
# curbweight                3.6197      2.398      1.510      0.134      -1.133       8.372
# enginesize               96.9579     34.214      2.834      0.005      29.147     164.769
# boreratio             -3161.4145   1828.428     -1.729      0.087   -6785.299     462.470
# stroke                -2520.3566   1251.931     -2.013      0.047   -5001.643     -39.070
# horsepower               68.8054     32.757      2.100      0.038       3.881     133.730
# peakrpm                   1.3285      0.825      1.610      0.110      -0.307       2.964
# citympg                  85.8021     89.714      0.956      0.341     -92.008     263.613
# fueltype_gas           -806.6328   1596.334     -0.505      0.614   -3970.515    2357.250
# aspiration_turbo       1401.8666   1175.829      1.192      0.236    -928.589    3732.322
# doornumber_two          151.0679    719.060      0.210      0.834   -1274.086    1576.222
# carbody_hardtop       -2290.8092   1704.959     -1.344      0.182   -5669.983    1088.365
# carbody_hatchback     -2670.5592   1569.368     -1.702      0.092   -5780.996     439.878
# carbody_sedan         -1655.7988   1625.524     -1.019      0.311   -4877.535    1565.938
# carbody_wagon         -3615.8713   1789.724     -2.020      0.046   -7163.046     -68.697
# drivewheel_rwd          706.5082    819.742      0.862      0.391    -918.195    2331.211
# enginelocation_rear    5207.5988   2980.751      1.747      0.083    -700.152    1.11e+04
# enginetype_dohcv      -1.094e-09   1.26e-09     -0.866      0.388    -3.6e-09    1.41e-09
# enginetype_l           1622.1391   1729.714      0.938      0.350   -1806.098    5050.376
# enginetype_ohc         4401.9838   1216.983      3.617      0.000    1989.963    6814.005
# enginetype_ohcf        3790.5129   2018.740      1.878      0.063    -210.565    7791.591
# enginetype_ohcv       -5227.7576   1553.406     -3.365      0.001   -8306.558   -2148.958
# cylindernumber_five    -1.12e+04   3527.701     -3.175      0.002   -1.82e+04   -4207.548
# cylindernumber_four   -1.308e+04   3693.384     -3.540      0.001   -2.04e+04   -5755.166
# cylindernumber_six    -1.055e+04   2592.480     -4.069      0.000   -1.57e+04   -5410.987
# cylindernumber_three  -6436.8390   5155.062     -1.249      0.214   -1.67e+04    3780.327
# cylindernumber_twelve  -1.62e+04   4239.991     -3.821      0.000   -2.46e+04   -7795.443
# cylindernumber_two    -3188.2960   4931.363     -0.647      0.519    -1.3e+04    6585.505
# fuelsystem_2bbl         -23.0038   1063.236     -0.022      0.983   -2130.303    2084.295
# fuelsystem_mfi        -4315.0608   2809.873     -1.536      0.128   -9884.138    1254.016
# fuelsystem_mpfi        -500.7446   1200.321     -0.417      0.677   -2879.742    1878.253
# fuelsystem_spdi       -3818.8548   1672.479     -2.283      0.024   -7133.653    -504.056
# fuelsystem_spfi        -595.2561   2734.521     -0.218      0.828   -6014.987    4824.475
# ==============================================================================
# Omnibus:                       20.201   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.447
# Skew:                           0.471   Prob(JB):                     5.53e-13
# Kurtosis:                       5.919   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.7e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
#use out test set to compare our predictions with the observed values

# %%
Y_test =test_df.price
test_df =stats.add_constant(test_df)
X_test = test_df[X_train.columns]

# %%
test_predictions=resluts_carprice.predict(X_test)

# %%
plot.scatter(test_predictions,Y_test)
plot.plot([5000,50000], [5000,50000], c='k', ls='--')
plot.xlabel('Predicted Price [$]')
plot.ylabel('Observed Price [$]')
plot.show()
